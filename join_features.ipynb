# %%
import pandas as pd

# %%
x_train_giovanni = pd.read_csv("x_train_preprocess_giovanni.csv", header = None)
x_train_davide = pd.read_csv("x_train_preprocess_davide.csv")

# %%
x_test_giovanni = pd.read_csv("x_test_preprocess_giovanni.csv", header = None)
x_test_davide = pd.read_csv("x_test_preprocess_davide.csv")

# %%
x_train_preprocessing = pd.concat([x_train_davide, x_train_giovanni], axis=1)

# %%
x_test_preprocessing = pd.concat([x_test_davide, x_test_giovanni], axis=1)

# %%
x_test_preprocessing
# Out:
#       Unnamed: 0  heart_rate_mean  heart_rate_std  heart_rate_max  \
# 0              0        70.276636        4.438959       74.797708
# 1              1        56.136634        2.292402       60.585277
# 2              2        82.234544       22.823698      130.331600
# 3              3        62.201561        0.894324       63.684188
# 4              4        60.836708        1.883145       64.240052
# ...          ...              ...             ...             ...
# 3406        3406        98.518553       24.782264      150.506030
# 3407        3407        65.866323       16.264606      116.048480
# 3408        3408        79.435681        5.153687       93.967539
# 3409        3409        82.214206        0.952887       84.375411
# 3410        3410       106.283518       13.516052      133.563796
#
#       heart_rate_min  heart_rate_median  heart_rate_iqr  heart_rate_skew  \
# 0          62.510604          72.162487        8.304185        -0.710603
# ...

# %%
x_train_preprocessing.to_csv('x_train_preprocess.csv')
x_test_preprocessing.to_csv('x_test_preprocess.csv')
