# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# %%
input_dim = 1 
output_dim = 32

import pickle
le_file_path = 'centerwaves.pkl'
with open(le_file_path, 'rb') as file:
    loaded_data = pickle.load(file)
centerpoints, centerwaves = loaded_data
print(loaded_data)
# Out:
# ([9, 0, 11, 7, 0], [array([  72.,   69.,   68.,   67.,   65.,   64.,   59.,   52.,   44.,
#          37.,   31.,   25.,   20.,   16.,   15.,   14.,   13.,   11.,
#           9.,    8.,    5.,    1.,    6.,   12.,   17.,   15.,    2.,
#          -8.,  -17.,  -27.,  -38.,  -50.,  -64.,  -82.,  -84.,  -73.,
#         -64.,  -57.,  -51.,  -45.,  -40.,  -36.,  -33.,  -30.,  -27.,
#         -24.,  -20.,  -17.,  -16.,  -12.,   -7.,   11.,   55.,  120.,
#         199.,  286.,  372.,  454.,  533.,  605.,  630.,  620.,  588.,
#         486.,  366.,  268.,  209.,  192.,  182.,  174.,  167.,  162.,
#         156.,  143.,  120.,   95.,   67.,   14.,  -57., -121., -147.,
#        -153., -158., -162., -164., -165., -165., -166., -166., -167.,
#        -167., -166., -163., -159., -155., -151., -145., -142., -144.,
#        -148., -149., -151., -153., -155., -157., -158., -159., -160.,
#        -162., -164., -165., -165., -164., -161., -159., -158., -156.,
# ...

# %%
x = centerwaves[0].reshape(1,-1,1)
x = LSTM(units=64, input_shape=(None, input_dim))(x)
x = Dense(units=output_dim, activation='softmax')(x)

print(x)
# Out:
# tf.Tensor(
# [[0.03008548 0.03976823 0.00907685 0.04637907 0.02802681 0.0349537
#   0.02737815 0.03341829 0.03449634 0.0424695  0.01917616 0.0155448
#   0.02200973 0.02780514 0.02051168 0.03653945 0.01873374 0.04207455
#   0.04712882 0.02643312 0.01620144 0.01295193 0.05414509 0.03056239
#   0.04257556 0.04133522 0.01909192 0.04110382 0.0652733  0.01962049
#   0.01938013 0.03574916]], shape=(1, 32), dtype=float32)
